# %%
#Импортируем необходимые библиотеки
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline 
sns.set(style="ticks")

# %%
data = pd.read_csv('crime.csv', sep=",")
data = data.drop('month', axis=1)
data = data.drop('Total_crimes', axis=1)

# %%
# Размер датасета - 205 строк, 14 колонок
data.shape
# Out:
# (205, 14)

# %%
total_count = data.shape[0]
print('Всего строк: {}'.format(total_count))
# Out:
# Всего строк: 205

# %%
# Список колонок
data.columns
# Out:
# Index(['Serious', 'Huge_damage', 'Ecological', 'Terrorism', 'Extremism',
#        'Murder', 'Harm_to_health', 'Rape', 'Theft', 'Vehicle_theft',
#        'Fraud_scam', 'Hooligan', 'Drugs', 'Weapons'],
#       dtype='str')

# %%
# Список колонок с типами данных
data.dtypes
# Out:
# Serious           float64
# Huge_damage       float64
# Ecological        float64
# Terrorism         float64
# Extremism         float64
# Murder            float64
# Harm_to_health    float64
# Rape              float64
# Theft             float64
# Vehicle_theft     float64
# Fraud_scam        float64
# Hooligan          float64
# Drugs             float64
# Weapons           float64
# dtype: object

# %%
# Проверим наличие пустых значений
# Цикл по колонкам датасета
for col in data.columns:
    # Количество пустых значений - все значения заполнены
    temp_null_count = data[data[col].isnull()].shape[0]
    print('{} - {}'.format(col, temp_null_count))
# Out:
# Serious - 0
# Huge_damage - 0
# Ecological - 0
# Terrorism - 0
# Extremism - 0
# Murder - 0
# Harm_to_health - 0
# Rape - 0
# Theft - 0
# Vehicle_theft - 0
# Fraud_scam - 0
# Hooligan - 0
# Drugs - 0
# Weapons - 0

# %%
# Основные статистические характеристки набора данных
data.describe()
# Out:
#              Serious   Huge_damage   Ecological    Terrorism   Extremism  \
# count     205.000000    205.000000   205.000000   205.000000  205.000000
# mean    59068.487805  38402.039024  2592.463415   197.839024   59.473171
# std     20501.515982  20755.286960  1028.101551   245.462645   42.070500
# min     15755.000000   7424.000000  1216.000000    12.000000    2.000000
# 25%     42135.000000  21813.000000  1888.000000    57.000000   26.000000
# 50%     51426.000000  26357.000000  2322.000000   103.000000   52.000000
# 75%     78407.000000  59282.000000  3034.000000   184.000000   87.000000
# max    108299.000000  87941.000000  6822.000000  1198.000000  174.000000
#
#             Murder  Harm_to_health         Rape          Theft  Vehicle_theft  \
# count   205.000000      205.000000   205.000000     205.000000     205.000000
# mean   1451.400000     3276.024390   463.580488   92647.560976    4101.414634
# ...

# %%
fig, ax = plt.subplots(figsize=(10,10)) 
sns.scatterplot(ax=ax, x='Extremism', y='Murder', data=data)
# Out:
# <Axes: xlabel='Extremism', ylabel='Murder'>

# %%
sns.pairplot(data)

# %%
fig, ax = plt.subplots(figsize=(10,10)) 
sns.distplot(data['Murder'])
# Out:
# C:\Users\yaros\AppData\Local\Temp\ipykernel_18108\613665596.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Murder'])
# <Axes: xlabel='Murder', ylabel='Density'>

# %%
sns.jointplot(x='Extremism', y='Murder', data=data)

# %%
sns.jointplot(x='Extremism', y='Murder', data=data, kind="hex")

# %%
sns.jointplot(x='Extremism', y='Murder', data=data, kind="kde")

# %%
sns.violinplot(x=data['Murder'])
# Out:
# <Axes: xlabel='Murder'>

# %%
# По вертикали
sns.boxplot(y=data['Murder'])
# Out:
# <Axes: ylabel='Murder'>

# %%
data.corr()
# Out:
#                  Serious  Huge_damage  Ecological  Terrorism  Extremism  \
# Serious         1.000000    -0.706613    0.430017   0.482598  -0.716503
# Huge_damage    -0.706613     1.000000   -0.358928  -0.284117   0.754239
# Ecological      0.430017    -0.358928    1.000000  -0.128444  -0.285047
# Terrorism       0.482598    -0.284117   -0.128444   1.000000  -0.366691
# Extremism      -0.716503     0.754239   -0.285047  -0.366691   1.000000
# Murder          0.930890    -0.740594    0.326567   0.656727  -0.714132
# Harm_to_health  0.909509    -0.806778    0.375154   0.532989  -0.734104
# Rape            0.826251    -0.627045    0.455456   0.487200  -0.605837
# Theft           0.814111    -0.597503    0.584345   0.177428  -0.595529
# Vehicle_theft   0.633995    -0.555388    0.500615   0.335346  -0.501913
# Fraud_scam     -0.136867     0.484090    0.096173  -0.383013   0.325328
# Hooligan        0.622689    -0.424816    0.045472   0.631847  -0.462450
# ...

# %%
data.corr(method='pearson')
# Out:
#                  Serious  Huge_damage  Ecological  Terrorism  Extremism  \
# Serious         1.000000    -0.706613    0.430017   0.482598  -0.716503
# Huge_damage    -0.706613     1.000000   -0.358928  -0.284117   0.754239
# Ecological      0.430017    -0.358928    1.000000  -0.128444  -0.285047
# Terrorism       0.482598    -0.284117   -0.128444   1.000000  -0.366691
# Extremism      -0.716503     0.754239   -0.285047  -0.366691   1.000000
# Murder          0.930890    -0.740594    0.326567   0.656727  -0.714132
# Harm_to_health  0.909509    -0.806778    0.375154   0.532989  -0.734104
# Rape            0.826251    -0.627045    0.455456   0.487200  -0.605837
# Theft           0.814111    -0.597503    0.584345   0.177428  -0.595529
# Vehicle_theft   0.633995    -0.555388    0.500615   0.335346  -0.501913
# Fraud_scam     -0.136867     0.484090    0.096173  -0.383013   0.325328
# Hooligan        0.622689    -0.424816    0.045472   0.631847  -0.462450
# ...

# %%
data.corr(method='kendall')
# Out:
#                  Serious  Huge_damage  Ecological  Terrorism  Extremism  \
# Serious         1.000000    -0.463915    0.350617   0.049440  -0.560270
# Huge_damage    -0.463915     1.000000   -0.148945   0.063536   0.579358
# Ecological      0.350617    -0.148945    1.000000  -0.183441  -0.197470
# Terrorism       0.049440     0.063536   -0.183441   1.000000  -0.066310
# Extremism      -0.560270     0.579358   -0.197470  -0.066310   1.000000
# Murder          0.764609    -0.584228    0.307299   0.055063  -0.576820
# Harm_to_health  0.742155    -0.581966    0.315185   0.015684  -0.608993
# Rape            0.601924    -0.445774    0.388780   0.088826  -0.467139
# Theft           0.631881    -0.368245    0.505668  -0.027668  -0.450644
# Vehicle_theft   0.449440    -0.355001    0.429583  -0.010887  -0.360212
# Fraud_scam     -0.097042     0.391066    0.002344   0.050350   0.230731
# Hooligan        0.763172    -0.563020    0.375305   0.010603  -0.601700
# ...

# %%
data.corr(method='spearman')
# Out:
#                  Serious  Huge_damage  Ecological  Terrorism  Extremism  \
# Serious         1.000000    -0.698620    0.501285   0.114965  -0.760124
# Huge_damage    -0.698620     1.000000   -0.249847  -0.023533   0.779875
# Ecological      0.501285    -0.249847    1.000000  -0.280539  -0.289718
# Terrorism       0.114965    -0.023533   -0.280539   1.000000  -0.163379
# Extremism      -0.760124     0.779875   -0.289718  -0.163379   1.000000
# Murder          0.926363    -0.812770    0.444926   0.123459  -0.763198
# Harm_to_health  0.917851    -0.815370    0.452056   0.097642  -0.787028
# Rape            0.805716    -0.640578    0.549814   0.176428  -0.666085
# Theft           0.830711    -0.591935    0.690892  -0.025503  -0.652112
# Vehicle_theft   0.640261    -0.542856    0.610255   0.003516  -0.521667
# Fraud_scam     -0.151905     0.549359    0.001801   0.037394   0.321339
# Hooligan        0.925324    -0.802285    0.514201   0.081392  -0.785938
# ...

# %%
sns.heatmap(data.corr())
# Out:
# <Axes: >

# %%
fig, ax = plt.subplots(1, 3, sharex='col', sharey='row', figsize=(15,4))
sns.heatmap(data.corr(method='pearson'), ax=ax[0])
sns.heatmap(data.corr(method='kendall'), ax=ax[1])
sns.heatmap(data.corr(method='spearman'), ax=ax[2])
fig.suptitle('Корреляционные матрицы, построенные различными методами')
ax[0].title.set_text('Pearson')
ax[1].title.set_text('Kendall')
ax[2].title.set_text('Spearman')
